# %% [markdown]
# # TOURISM AND TRAVEL IN LAVASA

# %% [markdown]
# CAC 2
# Exploratory Data Analysis
#
# The team must identify a Domain related to Lavasa  create a unique problem statement associated with the domain, and determine the attributes associated with the problem.
#
# Collect data using various techniques, perform Exploratory Data Analysis (with the help of Python), and Present the Key insights obtained from the analysis in a Chart

# %%
#importing required libraries for the project
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("lavasa.csv")  #importing the data set

# %%
data.head(5) #printing the top five rows of the data set
# Out:
#              Timestamp   AGE  GENDER CITY YOU ARE FROM?  PURPOSE OF VISIT  \
# 0  10/10/2023 18:40:26  24.0  FEMALE              Delhi           Student
# 1  10/10/2023 18:42:51  22.0    MALE            KOLKATA  Vacation, Others
# 2  10/10/2023 18:52:17  21.0  FEMALE             meerut           Student
# 3  10/10/2023 18:56:38  21.0  FEMALE     Pathanamthitta           Student
# 4  10/10/2023 19:03:08  18.0  FEMALE            Nagpur            Student
#
#   CATEGORY OF VISITORS WHERE DID YOU STAY? HOTEL CHARGES /DAY  \
# 0                 Solo        Celebrations          2000-3000
# 1               Couple              Ekaant         5000 above
# 2                 Solo        Celebrations          2000-3000
# 3               Family        Picnic House          4000-5000
# 4                 Solo        Celebrations          2000-3000
#
#                                    AMENITIES YOU GOT  STAFF SERVICE  ...  \
# ...

# %%
data.tail(5) #printing the top five rows of the data set
# Out:
#                Timestamp   AGE  GENDER CITY YOU ARE FROM?    PURPOSE OF VISIT  \
# 246  10/19/2023 22:54:25  24.0    MALE           Udaipur              Teacher
# 247  10/19/2023 23:00:24  30.0  FEMALE              Patna            Vacation
# 248  10/19/2023 23:04:55  23.0    MALE              Delhi  Vacation, Business
# 249  10/19/2023 23:16:47  30.0  FEMALE             Nagpur            Business
# 250  10/19/2023 23:48:13  22.0  FEMALE             Nagpur             Student
#
#     CATEGORY OF VISITORS WHERE DID YOU STAY? HOTEL CHARGES /DAY  \
# 246               Couple  Private Apartments          4000-5000
# 247                 Solo           Antariksh         5000 above
# 248                 Solo  Private Apartments          4000-5000
# 249                 Solo           Antariksh          2000-3000
# 250               Family        Celebrations          2000-3000
#
#                                      AMENITIES YOU GOT  STAFF SERVICE  ...  \
# ...

# %%
data.dtypes  #identifying the datatypes of the attributes
# Out:
# Timestamp                                            object
# AGE                                                 float64
# GENDER                                               object
# CITY YOU ARE FROM?                                   object
# PURPOSE OF VISIT                                     object
# CATEGORY OF VISITORS                                 object
# WHERE DID YOU STAY?                                  object
# HOTEL CHARGES /DAY                                   object
# AMENITIES YOU GOT                                    object
# STAFF SERVICE                                         int64
# How did You reach Lavasa?                            object
# Frequency of Visit                                   object
# Season of Visit                                      object
# Travel Convenience                                    int64
# Places you visited in Lavasa                         object
# Activities                                           object
# ...

# %%
data.shape #fetching the dimensions of the objects
# Out:
# (251, 24)

# %%
duplicate_rows= data[data.duplicated()]    #removing the duplicated rows

# %%
duplicate_rows.shape    #identifying the dimension of duplicate rows
# Out:
# (0, 24)

# %%
data.count()  #counting the number of entries/responses in the data set
# Out:
# Timestamp                                           251
# AGE                                                 247
# GENDER                                              251
# CITY YOU ARE FROM?                                  251
# PURPOSE OF VISIT                                    251
# CATEGORY OF VISITORS                                251
# WHERE DID YOU STAY?                                 251
# HOTEL CHARGES /DAY                                  251
# AMENITIES YOU GOT                                   251
# STAFF SERVICE                                       251
# How did You reach Lavasa?                           251
# Frequency of Visit                                  251
# Season of Visit                                     251
# Travel Convenience                                  251
# Places you visited in Lavasa                        251
# Activities                                          251
# How would you Rate the activities and attraction    251
# ...

# %%
data.isnull()
# Out:
#      Timestamp    AGE  GENDER  CITY YOU ARE FROM?  PURPOSE OF VISIT  \
# 0        False  False   False               False             False
# 1        False  False   False               False             False
# 2        False  False   False               False             False
# 3        False  False   False               False             False
# 4        False  False   False               False             False
# ..         ...    ...     ...                 ...               ...
# 246      False  False   False               False             False
# 247      False  False   False               False             False
# 248      False  False   False               False             False
# 249      False  False   False               False             False
# 250      False  False   False               False             False
#
#      CATEGORY OF VISITORS  WHERE DID YOU STAY?  HOTEL CHARGES /DAY  \
# 0                   False                False               False
# ...

# %%
print(data.isnull().sum())
# Out:
# Timestamp                                             0
# AGE                                                   4
# GENDER                                                0
# CITY YOU ARE FROM?                                    0
# PURPOSE OF VISIT                                      0
# CATEGORY OF VISITORS                                  0
# WHERE DID YOU STAY?                                   0
# HOTEL CHARGES /DAY                                    0
# AMENITIES YOU GOT                                     0
# STAFF SERVICE                                         0
# How did You reach Lavasa?                             0
# Frequency of Visit                                    0
# Season of Visit                                       0
# Travel Convenience                                    0
# Places you visited in Lavasa                          0
# Activities                                            0
# How would you Rate the activities and attraction      0
# ...

# %%
# df = data.fillna("N/A")

# %%
# print(df.isnull().sum())

# %%
df = data["AGE"]
print(df)
# Out:
# 0      24.0
# 1      22.0
# 2      21.0
# 3      21.0
# 4      18.0
#        ...
# 246    24.0
# 247    30.0
# 248    23.0
# 249    30.0
# 250    22.0
# Name: AGE, Length: 251, dtype: float64

# %%
df.describe()
# Out:
# count    247.000000
# mean      22.404858
# std        5.784586
# min       10.000000
# 25%       20.000000
# 50%       21.000000
# 75%       23.000000
# max       60.000000
# Name: AGE, dtype: float64

# %%
df=int(df.mean())

# %%
df
# Out:
# 22

# %%
data["AGE"].fillna(value =round(data.AGE.mean()), inplace = True)

# %%
# data = data.convert_dtypes

# %%
# data.dtyp

# %%
data.tail(30)
# Out:
#                Timestamp   AGE  GENDER CITY YOU ARE FROM?    PURPOSE OF VISIT  \
# 221  10/16/2023 17:41:58  22.0    MALE          Faridabad            Vacation
# 222  10/16/2023 22:13:30  21.0    MALE            Kolkata            Business
# 223  10/17/2023 11:17:47  23.0  FEMALE            kolkata             Student
# 224  10/17/2023 13:21:03  22.0  FEMALE             Kerala             Student
# 225  10/17/2023 13:25:45  27.0    MALE             Kerala             Student
# 226  10/17/2023 13:28:48  21.0    MALE            Kolkata             Student
# 227  10/17/2023 13:47:00  21.0  FEMALE              Delhi   Vacation, Student
# 228  10/17/2023 15:07:48  21.0  FEMALE             Meerut   Vacation, Student
# 229  10/17/2023 19:42:56  22.0  FEMALE              Noida            Vacation
# 230  10/18/2023 19:05:21  26.0    MALE             Kannur             Teacher
# 231  10/19/2023 16:02:17  20.0    MALE              Mandi             Student
# ...

# %%
data['CITY YOU ARE FROM?'] = data['CITY YOU ARE FROM?'].str.upper()

# %%
data.groupby('CITY YOU ARE FROM?')

# %% [markdown]
# # Detecting Outliers

# %%
sns.boxplot(x=data['AGE'])
# Out:
# <Axes: xlabel='AGE'>

# %%
sns.boxplot(x=data['CITY YOU ARE FROM?'])
# Out:
# <Axes: xlabel='CITY YOU ARE FROM?'>

# %%
data
# Out:
#                Timestamp   AGE  GENDER CITY YOU ARE FROM?    PURPOSE OF VISIT  \
# 0    10/10/2023 18:40:26  24.0  FEMALE              DELHI             Student
# 1    10/10/2023 18:42:51  22.0    MALE            KOLKATA    Vacation, Others
# 2    10/10/2023 18:52:17  21.0  FEMALE             MEERUT             Student
# 3    10/10/2023 18:56:38  21.0  FEMALE     PATHANAMTHITTA             Student
# 4    10/10/2023 19:03:08  18.0  FEMALE            NAGPUR              Student
# ..                   ...   ...     ...                ...                 ...
# 246  10/19/2023 22:54:25  24.0    MALE           UDAIPUR              Teacher
# 247  10/19/2023 23:00:24  30.0  FEMALE              PATNA            Vacation
# 248  10/19/2023 23:04:55  23.0    MALE              DELHI  Vacation, Business
# 249  10/19/2023 23:16:47  30.0  FEMALE             NAGPUR            Business
# 250  10/19/2023 23:48:13  22.0  FEMALE             NAGPUR             Student
#
# ...

# %%
female=0   #identifying the number of males and females in the dataset
male=0
for i in data['GENDER']:
    if i=="FEMALE":
        female=female+1
    else:
        male=male+1
print("female:",female,"male:",male)
# Out:
# female: 125 male: 126

# %%
data.loc[76, 'CITY YOU ARE FROM?'] = "N/A"
data.loc[30, 'CITY YOU ARE FROM?'] = "N/A"
data.loc[115, 'CITY YOU ARE FROM?'] = "KOLKATA"
data.loc[183, 'CITY YOU ARE FROM?'] = "N/A"
data.loc[215, 'CITY YOU ARE FROM?'] = "HYDERABAD"

# %%
data.head(35)
# Out:
#               Timestamp   AGE  GENDER CITY YOU ARE FROM?   PURPOSE OF VISIT  \
# 0   10/10/2023 18:40:26  24.0  FEMALE              DELHI            Student
# 1   10/10/2023 18:42:51  22.0    MALE            KOLKATA   Vacation, Others
# 2   10/10/2023 18:52:17  21.0  FEMALE             MEERUT            Student
# 3   10/10/2023 18:56:38  21.0  FEMALE     PATHANAMTHITTA            Student
# 4   10/10/2023 19:03:08  18.0  FEMALE            NAGPUR             Student
# 5   10/10/2023 19:04:44  21.0  FEMALE            KOLKATA           Vacation
# 6   10/10/2023 19:08:17  22.0  FEMALE             KERALA            Student
# 7   10/10/2023 19:12:05  20.0  FEMALE           KOLKATA            Vacation
# 8   10/10/2023 19:14:06  20.0  FEMALE            KOLKATA            Student
# 9   10/10/2023 19:20:06  18.0  FEMALE     RAJKOT GUJARAT            Student
# 10  10/10/2023 19:20:27  44.0  FEMALE            MEERUT              Others
# ...

# %%
data.head(218)
# Out:
#                Timestamp   AGE  GENDER CITY YOU ARE FROM?  PURPOSE OF VISIT  \
# 0    10/10/2023 18:40:26  24.0  FEMALE              DELHI           Student
# 1    10/10/2023 18:42:51  22.0    MALE            KOLKATA  Vacation, Others
# 2    10/10/2023 18:52:17  21.0  FEMALE             MEERUT           Student
# 3    10/10/2023 18:56:38  21.0  FEMALE     PATHANAMTHITTA           Student
# 4    10/10/2023 19:03:08  18.0  FEMALE            NAGPUR            Student
# ..                   ...   ...     ...                ...               ...
# 213  10/14/2023 21:32:57  15.0  FEMALE               PUNE          Vacation
# 214  10/14/2023 21:47:08  16.0    MALE               PUNE          Vacation
# 215  10/15/2023 20:21:17  19.0    MALE          HYDERABAD           Student
# 216  10/15/2023 20:21:31  21.0  FEMALE            KOLKATA           Student
# 217  10/15/2023 20:21:35  21.0    MALE           DURGAPUR           Student
#
# ...

# %%
sns.catplot(data=data,x="AGE",y="GENDER",aspect=25/10)

# %%
# data[data["PURPOSE OF VISIT"].str.contains(',', na=False)]

# %%
# dataf_for_purpose_of_vist = data
# split_df = dataf_for_purpose_of_vist["PURPOSE OF VISIT"].str.split(',', expand=True).stack().reset_index(level=1, drop=True).reset_index(name='PURPOSE OF VISIT REFINED')
# split_df

# %%
# plot_df = data.loc[:, ['PURPOSE OF VISIT']]
# plot_df['PURPOSE OF VISIT'] = data['PURPOSE OF VISIT'].str.strip()
# plot_df['PURPOSE OF VISIT'] = data['PURPOSE OF VISIT'].str.split(',')
# plot_df = plot_df.explode('PURPOSE OF VISIT').reset_index(drop=True)
# plot_df.loc[:, ['PURPOSE OF VISIT']] = plot_df.loc[:, ['PURPOSE OF VISIT']]
plot_df1 = data.loc[:, ['PURPOSE OF VISIT','GENDER']]
plot_df1['first_item'] = plot_df1['PURPOSE OF VISIT'].str.split(',').str[0]
sns.catplot(data=plot_df1, x='first_item', y='GENDER',aspect=3)

# %%
# df = data.loc[:, ['PURPOSE OF VISIT']]

# %%
# df

# %%
data.isna().any()
# Out:
# Timestamp                                           False
# AGE                                                 False
# GENDER                                              False
# CITY YOU ARE FROM?                                  False
# PURPOSE OF VISIT                                    False
# CATEGORY OF VISITORS                                False
# WHERE DID YOU STAY?                                 False
# HOTEL CHARGES /DAY                                  False
# AMENITIES YOU GOT                                   False
# STAFF SERVICE                                       False
# How did You reach Lavasa?                           False
# Frequency of Visit                                  False
# Season of Visit                                     False
# Travel Convenience                                  False
# Places you visited in Lavasa                        False
# Activities                                          False
# ...

# %%
plot_df1 = data.loc[:, ['AMENITIES YOU GOT','WHERE DID YOU STAY?']]
# plot_df1['AMENITIES YOU GOT'] = data['AMENITIES YOU GOT'].str.strip()
# plot_df1['AMENITIES YOU GOT'] = data['AMENITIES YOU GOT'].str.split(',')
# plot_df1 = plot_df1.explode('AMENITIES YOU GOT').reset_index(drop=True)
# plot_df1.loc[:, ['AMENITIES YOU GOT']] = plot_df1.loc[:, ['AMENITIES YOU GOT']]

# %%
plot_df1['first_item'] = plot_df1['AMENITIES YOU GOT'].str.split(',').str[0]

# %%
plot_df1
# Out:
#                                      AMENITIES YOU GOT WHERE DID YOU STAY?  \
# 0                     Room service and Wifi, Game room        Celebrations
# 1    Swimming pool, Gym, Lobby and Bar, Restrauant,...              Ekaant
# 2                                           Restrauant        Celebrations
# 3                                Room service and Wifi        Picnic House
# 4                                           Restrauant        Celebrations
# ..                                                 ...                 ...
# 246  Swimming pool, Gym, Lobby and Bar, Restrauant,...  Private Apartments
# 247  Swimming pool, Gym, Lobby and Bar, Restrauant,...           Antariksh
# 248                  Restrauant, Room service and Wifi  Private Apartments
# 249                  Restrauant, Room service and Wifi           Antariksh
# 250                                     Gym, Game room        Celebrations
#
#                 first_item
# 0    Room service and Wifi
# ...

# %%
sns.catplot(data=plot_df1, x='first_item', y='WHERE DID YOU STAY?',aspect=3)

# %%
plot_df1 = data.loc[:, ['Places you visited in Lavasa','How would you Rate the activities and attraction']]
plot_df1['first_item'] = plot_df1['Places you visited in Lavasa'].str.split(',').str[0]
sns.catplot(data=plot_df1, x='first_item', y='How would you Rate the activities and attraction',aspect=3)
plot_df1
# Out:
#                           Places you visited in Lavasa  \
# 0    Christ (Deemed to be University) , Pune Lavasa...
# 1    Christ (Deemed to be University) , Pune Lavasa...
# 2    Christ (Deemed to be University) , Pune Lavasa...
# 3    Christ (Deemed to be University) , Pune Lavasa...
# 4    Christ (Deemed to be University) , Pune Lavasa...
# ..                                                 ...
# 246  Christ (Deemed to be University) , Pune Lavasa...
# 247  Christ (Deemed to be University) , Pune Lavasa...
# 248  Lingya Waterfalls, Town Hall, Dasve Viewpoint,...
# 249          Lingya Waterfalls, Temghar Dam, Town Hall
# 250  Christ (Deemed to be University) , Pune Lavasa...
#
#      How would you Rate the activities and attraction  \
# 0                                                   3
# 1                                                   5
# 2                                                   1
# 3                                                   3
# ...

# %%
# plot_df1 = data.loc[:, ['Places you visited in Lavasa']]
# # plot_df1['AMENITIES YOU GOT'] = data['AMENITIES YOU GOT'].str.strip()
# plot_df1['Places you visited in Lavasa'] = data['Places you visited in Lavasa'].str.split(',')
# plot_df1 = plot_df1.explode('Places you visited in Lavasa').reset_index(drop=True)
# plot_df1.loc[:, ['Places you visited in Lavasa']] = plot_df1.loc[:, ['Places you visited in Lavasa']]
# sns.catplot(data=data, x=plot_df1['Places you visited in Lavasa'], y='How would you Rate the activities and attraction',aspect=25/6)

# %%
# plot_df1 = data.loc[:, ['Activities']]
# # plot_df1['AMENITIES YOU GOT'] = data['AMENITIES YOU GOT'].str.strip()
# plot_df1['Activities'] = data['Activities'].str.split(',')
# plot_df1 = plot_df1.explode('Activities').reset_index(drop=True)
# plot_df1.loc[:, ['Activities']] = plot_df1.loc[:, ['Activities']]
# sns.catplot(data=data, x=plot_df1['Activities'], y='How would you Rate the activities and attraction',aspect=25/6)

plot_df1 = data.loc[:, ['Activities','How would you Rate the activities and attraction']]
plot_df1['first_item'] = plot_df1['Activities'].str.split(',').str[0]
sns.catplot(data=plot_df1, x='first_item', y='How would you Rate the activities and attraction',aspect=3)
plot_df1
# Out:
#                                             Activities  \
# 0                                               Others
# 1    Trackless Train, Water sport, Trekking, Bird W...
# 2                                             Trekking
# 3                                               Others
# 4                                Water sport, Trekking
# ..                                                 ...
# 246  Trackless Train, Water sport, Trekking, Bird W...
# 247  Trackless Train, Water sport, Trekking, Bird W...
# 248          Trekking, Bird Watching, Waterfall Safari
# 249                    Bird Watching, Waterfall Safari
# 250                                      Bird Watching
#
#      How would you Rate the activities and attraction       first_item
# 0                                                   3           Others
# 1                                                   5  Trackless Train
# 2                                                   1         Trekking
# ...

# %%
# plot_df1 = data.loc[:, ['Restaurants You Visited']]
# # plot_df1['AMENITIES YOU GOT'] = data['AMENITIES YOU GOT'].str.strip()
# plot_df1['Restaurants You Visited'] = data['Restaurants You Visited'].str.split(',')
# plot_df1 = plot_df1.explode('Restaurants You Visited').reset_index(drop=True)
# plot_df1.loc[:, ['Restaurants You Visited']] = plot_df1.loc[:, ['Restaurants You Visited']]
# sns.catplot(data=data, x=plot_df1['Restaurants You Visited'], y='Worth of Money',aspect=25/4)
plot_df1 = data.loc[:, ['Restaurants You Visited','Worth of Money']]
plot_df1['first_item'] = plot_df1['Restaurants You Visited'].str.split(',').str[0]
sns.catplot(data=plot_df1, x='first_item', y='Worth of Money',aspect=3)
plot_df1
# Out:
#                                Restaurants You Visited  Worth of Money  \
# 0    Hotel Yuvraj, Hotel Shree Pure Veg, American D...               4
# 1    Hotel Ashrirwad, Hotel Garava, Hotel Yuvraj, H...               1
# 2      Hotel Ashrirwad, Hotel Yuvraj, College Canteens               3
# 3    Hotel Yuvraj, Hotel Shree Pure Veg, College Ca...               4
# 4    Hotel Ashrirwad, Hotel Garava, Hotel Shree Pur...               3
# ..                                                 ...             ...
# 246  Popsicles Cafe, Hotel Sai, College Canteens, S...               5
# 247  Hotel Ashrirwad, Hotel Garava, Hotel Yuvraj, H...               5
# 248  Hotel Ashrirwad, Hotel Garava, Hotel Yuvraj, S...               4
# 249   Hotel Garava, Hotel Yuvraj, Hotel Shree Pure Veg               1
# 250                       Hotel Shree Pure Veg, Others               3
#
#                first_item
# 0            Hotel Yuvraj
# 1         Hotel Ashrirwad
# 2         Hotel Ashrirwad
# ...

# %%
data = data.drop(['Timestamp','Improvements needed'], axis = 1)

# %%
data
# Out:
#       AGE  GENDER CITY YOU ARE FROM?    PURPOSE OF VISIT CATEGORY OF VISITORS  \
# 0    24.0  FEMALE              DELHI             Student                 Solo
# 1    22.0    MALE            KOLKATA    Vacation, Others               Couple
# 2    21.0  FEMALE             MEERUT             Student                 Solo
# 3    21.0  FEMALE     PATHANAMTHITTA             Student               Family
# 4    18.0  FEMALE            NAGPUR              Student                 Solo
# ..    ...     ...                ...                 ...                  ...
# 246  24.0    MALE           UDAIPUR              Teacher               Couple
# 247  30.0  FEMALE              PATNA            Vacation                 Solo
# 248  23.0    MALE              DELHI  Vacation, Business                 Solo
# 249  30.0  FEMALE             NAGPUR            Business                 Solo
# 250  22.0  FEMALE             NAGPUR             Student               Family
#
# ...

# %%
sns.lineplot(x="WHERE DID YOU STAY?", y="HOTEL CHARGES /DAY",hue="STAFF SERVICE",data=data,)
# Out:
# <Axes: xlabel='WHERE DID YOU STAY?', ylabel='HOTEL CHARGES /DAY'>

# %%
gender=[male,female]
gender_labels=['male','female']
plt.pie(gender,labels=gender_labels,autopct='%1.1f%%')  #ratio of men and women
# Out:
# ([<matplotlib.patches.Wedge at 0x23039f680d0>,
# ...
#  [Text(-0.0068839747304848325, 1.0999784592854127, 'male'),
#   Text(0.006884077717900352, -1.0999784586408836, 'female')],
#  [Text(-0.003754895307537181, 0.5999882505193159, '50.2%'),
#   Text(0.0037549514824911003, -0.5999882501677546, '49.8%')])

# %%
pip install geopandas
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/51.1 kB ? eta -:--:--
#      ------------------------------ ------- 41.0/51.1 kB 991.0 kB/s eta 0:00:01
#      -------------------------------------- 51.1/51.1 kB 648.8 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      ---------------------------------------- 61.2/61.2 kB 1.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ------ --------------------------------- 0.2/1.1 MB 5.3 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.3/1.1 MB 3.9 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.5/1.1 MB 4.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.6/1.1 MB 3.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 0.8/1.1 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 0.9/1.1 MB 3.5 MB/s eta 0:00:01
# ...
