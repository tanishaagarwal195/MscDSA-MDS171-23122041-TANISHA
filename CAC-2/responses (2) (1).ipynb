# %% [markdown]
# # TOURISM AND TRAVEL IN LAVASA

# %% [markdown]
# # CAC - 2 : EXPLORATORY DATA ANALYSIS
# The team must identify a domain related to Lavasa , create a unique problem statement associated with the domain and determine the attributes associated with the problem.

# %% [markdown]
# # Problem statement-
# To enhance the tourist experience in Lavasa, we aim to understand the preferences and needs of visitors. Our goal is to identify key factors that influence tourist's satisfaction and their decision to visit Lavasa

# %% [markdown]
# # KEY ATTRIBUTES
#
# 1.)Types of visitors
#
# 2.)Accomodation type
#
# 3.)Transportation type
#
# 4.)Activities and attraction spots
#
# 5.)Dining prefrences
#
# 6.)Satisfaction and feedback

# %% [markdown]
# # GROUP 5:
#
# Mayuri Ubale          - 23122139
#
# Yashi                 - 23122144
#
# Tanisha Agarwal       - 23122041
#
# Sudeshna Ghosh        - 23122134

# %%
#importing the libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#reading the csv file and importing the data set
data=pd.read_csv("lavasa (1).csv")

# %%
#printing the first five rows of the data 
data.head(5)
# Out:
#              Timestamp   AGE  GENDER CITY YOU ARE FROM?  PURPOSE OF VISIT  \
# 0  10/10/2023 18:40:26  24.0  FEMALE              Delhi           Student
# 1  10/10/2023 18:42:51  22.0    MALE            KOLKATA  Vacation, Others
# 2  10/10/2023 18:52:17  21.0  FEMALE             meerut           Student
# 3  10/10/2023 18:56:38  21.0  FEMALE     Pathanamthitta           Student
# 4  10/10/2023 19:03:08  18.0  FEMALE            Nagpur            Student
#
#   CATEGORY OF VISITORS WHERE DID YOU STAY? HOTEL CHARGES /DAY  \
# 0                 Solo        Celebrations          2000-3000
# 1               Couple              Ekaant         5000 above
# 2                 Solo        Celebrations          2000-3000
# 3               Family        Picnic House          4000-5000
# 4                 Solo        Celebrations          2000-3000
#
#                                    AMENITIES YOU GOT  STAFF SERVICE  ...  \
# ...

# %%
#printing the last five rows of the data
data.tail(5)
# Out:
#                Timestamp   AGE  GENDER CITY YOU ARE FROM?    PURPOSE OF VISIT  \
# 246  10/19/2023 22:54:25  24.0    MALE           Udaipur              Teacher
# 247  10/19/2023 23:00:24  30.0  FEMALE              Patna            Vacation
# 248  10/19/2023 23:04:55  23.0    MALE              Delhi  Vacation, Business
# 249  10/19/2023 23:16:47  30.0  FEMALE             Nagpur            Business
# 250  10/19/2023 23:48:13  22.0  FEMALE             Nagpur             Student
#
#     CATEGORY OF VISITORS WHERE DID YOU STAY? HOTEL CHARGES /DAY  \
# 246               Couple  Private Apartments          4000-5000
# 247                 Solo           Antariksh         5000 above
# 248                 Solo  Private Apartments          4000-5000
# 249                 Solo           Antariksh          2000-3000
# 250               Family        Celebrations          2000-3000
#
#                                      AMENITIES YOU GOT  STAFF SERVICE  ...  \
# ...

# %%
# identifying the datatypes of the attributes
data.dtypes
# Out:
# Timestamp                                            object
# AGE                                                 float64
# GENDER                                               object
# CITY YOU ARE FROM?                                   object
# PURPOSE OF VISIT                                     object
# CATEGORY OF VISITORS                                 object
# WHERE DID YOU STAY?                                  object
# HOTEL CHARGES /DAY                                   object
# AMENITIES YOU GOT                                    object
# STAFF SERVICE                                         int64
# How did You reach Lavasa?                            object
# Frequency of Visit                                   object
# Season of Visit                                      object
# Travel Convenience                                    int64
# Places you visited in Lavasa                         object
# Activities                                           object
# ...

# %%
#fetching the dimensions of the data
data.shape
# Out:
# (251, 24)

# %%
#checking for the duplicate data
duplicate_rows= data[data.duplicated()]
duplicate_rows.shape
# Out:
# (0, 24)

# %%
#counts the number of non empty data for each column
data.count()
# Out:
# Timestamp                                           251
# AGE                                                 247
# GENDER                                              251
# CITY YOU ARE FROM?                                  251
# PURPOSE OF VISIT                                    251
# CATEGORY OF VISITORS                                251
# WHERE DID YOU STAY?                                 251
# HOTEL CHARGES /DAY                                  251
# AMENITIES YOU GOT                                   251
# STAFF SERVICE                                       251
# How did You reach Lavasa?                           251
# Frequency of Visit                                  251
# Season of Visit                                     251
# Travel Convenience                                  251
# Places you visited in Lavasa                        251
# Activities                                          251
# How would you Rate the activities and attraction    251
# ...

# %%
#checks if the data is null or not
data.isnull()
# Out:
#      Timestamp    AGE  GENDER  CITY YOU ARE FROM?  PURPOSE OF VISIT  \
# 0        False  False   False               False             False
# 1        False  False   False               False             False
# 2        False  False   False               False             False
# 3        False  False   False               False             False
# 4        False  False   False               False             False
# ..         ...    ...     ...                 ...               ...
# 246      False  False   False               False             False
# 247      False  False   False               False             False
# 248      False  False   False               False             False
# 249      False  False   False               False             False
# 250      False  False   False               False             False
#
#      CATEGORY OF VISITORS  WHERE DID YOU STAY?  HOTEL CHARGES /DAY  \
# 0                   False                False               False
# ...

# %%
print(data.isnull().sum()) #printing the sum of count of null rows
# Out:
# Timestamp                                             0
# AGE                                                   4
# GENDER                                                0
# CITY YOU ARE FROM?                                    0
# PURPOSE OF VISIT                                      0
# CATEGORY OF VISITORS                                  0
# WHERE DID YOU STAY?                                   0
# HOTEL CHARGES /DAY                                    0
# AMENITIES YOU GOT                                     0
# STAFF SERVICE                                         0
# How did You reach Lavasa?                             0
# Frequency of Visit                                    0
# Season of Visit                                       0
# Travel Convenience                                    0
# Places you visited in Lavasa                          0
# Activities                                            0
# How would you Rate the activities and attraction      0
# ...

# %%
# df = data.fillna("N/A")

# %%
# print(df.isnull().sum())

# %%
df = data["AGE"]
print(df)   #printing a particular column - AGE
# Out:
# 0      24.0
# 1      22.0
# 2      21.0
# 3      21.0
# 4      18.0
#        ...
# 246    24.0
# 247    30.0
# 248    23.0
# 249    30.0
# 250    22.0
# Name: AGE, Length: 251, dtype: float64

# %%
df.describe()  #describing the data - age
# Out:
# count    247.000000
# mean      22.404858
# std        5.784586
# min       10.000000
# 25%       20.000000
# 50%       21.000000
# 75%       23.000000
# max       60.000000
# Name: AGE, dtype: float64

# %%
df=int(df.mean())  #finding the mean value of age
df
# Out:
# 22

# %%
data["AGE"].fillna(value =round(data.AGE.mean()), inplace = True)  #replacing the null space with mean value of the age

# %%
data.tail(30) #checking if the value is replaced or not
# Out:
#                Timestamp   AGE  GENDER CITY YOU ARE FROM?    PURPOSE OF VISIT  \
# 221  10/16/2023 17:41:58  22.0    MALE          Faridabad            Vacation
# 222  10/16/2023 22:13:30  21.0    MALE            Kolkata            Business
# 223  10/17/2023 11:17:47  23.0  FEMALE            kolkata             Student
# 224  10/17/2023 13:21:03  22.0  FEMALE             Kerala             Student
# 225  10/17/2023 13:25:45  27.0    MALE             Kerala             Student
# 226  10/17/2023 13:28:48  21.0    MALE            Kolkata             Student
# 227  10/17/2023 13:47:00  21.0  FEMALE              Delhi   Vacation, Student
# 228  10/17/2023 15:07:48  21.0  FEMALE             Meerut   Vacation, Student
# 229  10/17/2023 19:42:56  22.0  FEMALE              Noida            Vacation
# 230  10/18/2023 19:05:21  26.0    MALE             Kannur             Teacher
# 231  10/19/2023 16:02:17  20.0    MALE              Mandi             Student
# ...

# %% [markdown]
# # Detecting outliers

# %%
sns.boxplot(x=data['AGE'])  #identifying outliers in the age group
# Out:
# <Axes: xlabel='AGE'>

# %%
data['CITY YOU ARE FROM?'] = data['CITY YOU ARE FROM?'].str.upper()  #converting the city strings to upper case

# %%
data  #Printing the values
# Out:
#                Timestamp   AGE  GENDER CITY YOU ARE FROM?    PURPOSE OF VISIT  \
# 0    10/10/2023 18:40:26  24.0  FEMALE              DELHI             Student
# 1    10/10/2023 18:42:51  22.0    MALE            KOLKATA    Vacation, Others
# 2    10/10/2023 18:52:17  21.0  FEMALE             MEERUT             Student
# 3    10/10/2023 18:56:38  21.0  FEMALE     PATHANAMTHITTA             Student
# 4    10/10/2023 19:03:08  18.0  FEMALE            NAGPUR              Student
# ..                   ...   ...     ...                ...                 ...
# 246  10/19/2023 22:54:25  24.0    MALE           UDAIPUR              Teacher
# 247  10/19/2023 23:00:24  30.0  FEMALE              PATNA            Vacation
# 248  10/19/2023 23:04:55  23.0    MALE              DELHI  Vacation, Business
# 249  10/19/2023 23:16:47  30.0  FEMALE             NAGPUR            Business
# 250  10/19/2023 23:48:13  22.0  FEMALE             NAGPUR             Student
#
# ...

# %%
#correcting all the error values in the city data
data.loc[76, 'CITY YOU ARE FROM?'] = "N/A"
data.loc[30, 'CITY YOU ARE FROM?'] = "N/A"
data.loc[115, 'CITY YOU ARE FROM?'] = "KOLKATA"
data.loc[183, 'CITY YOU ARE FROM?'] = "N/A"
data.loc[215, 'CITY YOU ARE FROM?'] = "HYDERABAD"

# %%
data.head(218)  #checking if the values are replaced or not
# Out:
#                Timestamp   AGE  GENDER CITY YOU ARE FROM?  PURPOSE OF VISIT  \
# 0    10/10/2023 18:40:26  24.0  FEMALE              DELHI           Student
# 1    10/10/2023 18:42:51  22.0    MALE            KOLKATA  Vacation, Others
# 2    10/10/2023 18:52:17  21.0  FEMALE             MEERUT           Student
# 3    10/10/2023 18:56:38  21.0  FEMALE     PATHANAMTHITTA           Student
# 4    10/10/2023 19:03:08  18.0  FEMALE            NAGPUR            Student
# ..                   ...   ...     ...                ...               ...
# 213  10/14/2023 21:32:57  15.0  FEMALE               PUNE          Vacation
# 214  10/14/2023 21:47:08  16.0    MALE               PUNE          Vacation
# 215  10/15/2023 20:21:17  19.0    MALE          HYDERABAD           Student
# 216  10/15/2023 20:21:31  21.0  FEMALE            KOLKATA           Student
# 217  10/15/2023 20:21:35  21.0    MALE           DURGAPUR           Student
#
# ...

# %%
data = data.drop(['Timestamp'], axis = 1)  #dropping the unneccesary column as we don,t need time stamp for our analysis
data
# Out:
#       AGE  GENDER CITY YOU ARE FROM?    PURPOSE OF VISIT CATEGORY OF VISITORS  \
# 0    24.0  FEMALE              DELHI             Student                 Solo
# 1    22.0    MALE            KOLKATA    Vacation, Others               Couple
# 2    21.0  FEMALE             MEERUT             Student                 Solo
# 3    21.0  FEMALE     PATHANAMTHITTA             Student               Family
# 4    18.0  FEMALE            NAGPUR              Student                 Solo
# ..    ...     ...                ...                 ...                  ...
# 246  24.0    MALE           UDAIPUR              Teacher               Couple
# 247  30.0  FEMALE              PATNA            Vacation                 Solo
# 248  23.0    MALE              DELHI  Vacation, Business                 Solo
# 249  30.0  FEMALE             NAGPUR            Business                 Solo
# 250  22.0  FEMALE             NAGPUR             Student               Family
#
# ...

# %% [markdown]
# # DATA VISUALISATION

# %%
ages = data['AGE']
# Creating a histogram of age distribution
plt.figure(figsize=(10, 6))  
plt.hist(ages, bins=30, edgecolor='black',facecolor='purple')  
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# Insights - "Mostly Young adults are visting Lavasa as they prefer peace and serendipity over the hustle-bustle of city Life"

# %%
# sns.catplot(data=data,x="AGE",color = 'grey')

# %%
count_data = data['GENDER'].value_counts()
# Creating a pie chart for gender distribution
plt.figure(figsize=(6, 6))
plt.pie(count_data, labels=count_data.index, autopct='%.1f%%', startangle=140)
plt.title('Gender Distribution')
plt.axis('equal')
plt.show()

# %% [markdown]
# Insights-"The ratio of males to females is prefectly balanced creating an environment with equal opportunities for all"

# %%
city_counts = data['CITY YOU ARE FROM?'].value_counts().reset_index() #cleaning this data for better visualisation

for i in range(len(data["CITY YOU ARE FROM?"])):
    data["CITY YOU ARE FROM?"][i] = data["CITY YOU ARE FROM?"][i].strip()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9600\1166661115.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["CITY YOU ARE FROM?"][i] = data["CITY YOU ARE FROM?"][i].strip()
# C:\Users\USER\AppData\Local\Temp\ipykernel_9600\1166661115.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["CITY YOU ARE FROM?"][i] = data["CITY YOU ARE FROM?"][i].strip()
# C:\Users\USER\AppData\Local\Temp\ipykernel_9600\1166661115.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
data["CITY YOU ARE FROM?"].unique()
# Out:
# array(['DELHI', 'KOLKATA', 'MEERUT', 'PATHANAMTHITTA', 'NAGPUR', 'KERALA',
#        'RAJKOT GUJARAT', 'RAJKOT', 'PUNE', 'SEONI MP', 'AMRAVATI',
#        'SEONI', 'AURANGABAD', 'RANCHI', 'AGRA', 'N/A', 'ANJANGAON SURJI',
#        'MUMBAI', 'BARGHAT', 'KANNUR', 'GOA', 'VISHAKAPATANAM',
#        'HYDERABAD', 'HINGANGHAT', 'CHANDRAPUR', 'BHANDARA', 'ACHALPUR',
#        'COIMBATORE', 'SHILLONG', 'LUCKNOW', 'JODHPUR', 'NARKHED', 'PATNA',
#        'GURUGRAM', 'GWALIOR', 'SHIMOGA', 'KERALA, PALAKKAD', 'THRISSUR',
#        'NANDED', 'KERALA, THRISSUR', 'NASHIK', 'KHOWAI', 'UTTRAKHAND',
#        'DUBAI', 'BHOPAL', 'JEYPORE', 'KALMESHAWAR', 'SOANER',
#        'IT PARK, NAGPUR', 'ASSAM', 'CHENNAI', 'ROURKELA', 'NOIDA',
#        'VADODARA', 'ALAPPUZHA', 'KOCHI', 'NILGIRIS', 'KANPUT', 'BAREILLY',
#        'SOJAT CITY', 'GURGAON', 'KOTTAYAM', 'MANGALORE', 'TRIVANDRUM',
#        'AHMEDABAD', 'KANPUR', 'JAIPUR', 'DEHRADUN', 'DURGAPUR', 'SIKAR',
# ...

# %%
#plotting the cities
sns.set_theme(style="ticks")
fig, ax = plt.subplots(figsize=(100, 6))
sns.histplot(
    data,
    x="CITY YOU ARE FROM?",
    edgecolor=".3",
    linewidth=2,log_scale=True,
    color = 'teal'
    
)
plt.xlabel('CATEGORY OF VISIT')
# Out:
# Text(0.5, 0, 'CATEGORY OF VISIT')

# %% [markdown]
# Insights-"We see that Lavasa is very Diversified , but still the majority of the crowd is from the same state"

# %%
#plotting the category of visitors from the data set
sns.set_theme(style="ticks")
fig, ax = plt.subplots(figsize=(10, 6))
sns.histplot(
    data,
    x="CATEGORY OF VISITORS",
    edgecolor=".3",
    linewidth=2,log_scale=True,
    color = 'yellow'
    
)
plt.xlabel('CATEGORY OF VISIT')
# Out:
# Text(0.5, 0, 'CATEGORY OF VISIT')

# %% [markdown]
# Insights-"We observe that mostly solo travellers visit lavasa to find themselves and their inner voice"

# %%
#finding where the visitors preferred to stay
count_data = data['WHERE DID YOU STAY?'].value_counts()

# Creating a pie chart for better visualisation
plt.figure(figsize=(6, 6)) 
plt.pie(count_data, labels=count_data.index, autopct='%1.1f%%', startangle=140)
plt.title('STAY')
plt.axis('equal')
plt.show()

# %% [markdown]
# Insights-"We see that people prefer private apartments over other accomodations"

# %%
charges = data['HOTEL CHARGES /DAY']
# Creating a histogram of Hotel charges per day
plt.figure(figsize=(10, 6))  
plt.hist(charges, bins=30, edgecolor='yellow',facecolor='red') 
plt.xlabel('Charges')
plt.ylabel('Count')
plt.title('Hotel charges/day')
plt.show()

# %% [markdown]
# Insights-"We see that the charges are budget friendly"

# %%
#Transportation preferences
sns.set_theme(style="ticks")
fig, ax = plt.subplots(figsize=(10, 6))
sns.histplot(
    data,
    x="How did You reach Lavasa?",
    edgecolor=".3",
    linewidth=2,log_scale=True,facecolor='orange'
)
plt.xlabel('How did You reach Lavasa?')
# Out:
# Text(0.5, 0, 'How did You reach Lavasa?')

# %% [markdown]
# Insights-"Due to the lack of public transport , people prefer to travel via private vehicles"

# %% [markdown]
# GAP : "Lack of Availablity of public transport , even in emergency situations there is very less connectivity to the main city [PUNE] in terms of transportation"

# %%
season = data['Season of Visit ']
#Create a histogram to find the best season to visit Lavasa
plt.figure(figsize=(7, 6)) 
plt.hist(season, bins=30, edgecolor='purple',linewidth=2 , facecolor='pink')  
plt.xlabel('season')
plt.ylabel('Count')
plt.title('Tourist season')
plt.show()

# %% [markdown]
# Insights-"People prefer travelling to Lavasa in Monsoon season more than any other"

# %%
#Food preferences
plt.figure(figsize=(6, 6))
sns.histplot(data=data,x="Food preferences",color='teal')
# Out:
# <Axes: xlabel='Food preferences', ylabel='Count'>

# %% [markdown]
# Insights-"We observe that the ratio of vegetarians to non-vegetarians is quite balanced"

# %%
#Travel convinience
plt.figure(figsize=(20, 5))
sns.catplot(data=data,x="Travel Convenience ",color='blue')

# %% [markdown]
# Insights-"The travel convenience id moderately difficult for people , due to the presence of steepy roads and lack of streetlights at night"

# %%
#Relationship between the gender and age of people visiting lavasa
sns.catplot(data=data,x="AGE",y="GENDER",aspect=25/10,color="green")

# %%
# plot_df1['AMENITIES YOU GOT'] = data['AMENITIES YOU GOT'].str.strip()
# plot_df1['AMENITIES YOU GOT'] = data['AMENITIES YOU GOT'].str.split(',')
# plot_df1 = plot_df1.explode('AMENITIES YOU GOT').reset_index(drop=True)
# plot_df1.loc[:, ['AMENITIES YOU GOT']] = plot_df1.loc[:, ['AMENITIES YOU GOT']]

# %%
df1 = data.loc[:,['PURPOSE OF VISIT','GENDER']] #separating columns with multiple values and making a new column with the first preferred value
df1['purpose'] = df1['PURPOSE OF VISIT'].str.split(',').str[0]
df1
# Out:
#        PURPOSE OF VISIT  GENDER   purpose
# 0               Student  FEMALE   Student
# 1      Vacation, Others    MALE  Vacation
# 2               Student  FEMALE   Student
# 3               Student  FEMALE   Student
# 4               Student  FEMALE   Student
# ..                  ...     ...       ...
# 246             Teacher    MALE   Teacher
# 247            Vacation  FEMALE  Vacation
# 248  Vacation, Business    MALE  Vacation
# 249            Business  FEMALE  Business
# 250             Student  FEMALE   Student
#
# [251 rows x 3 columns]

# %%
df2 = data.loc[:, ['AMENITIES YOU GOT','WHERE DID YOU STAY?']] #separating columns with multiple values and making a new column with the first preferred value
df2['amenities'] = df2['AMENITIES YOU GOT'].str.split(',').str[0]
df2
# Out:
#                                      AMENITIES YOU GOT WHERE DID YOU STAY?  \
# 0                     Room service and Wifi, Game room        Celebrations
# 1    Swimming pool, Gym, Lobby and Bar, Restrauant,...              Ekaant
# 2                                           Restrauant        Celebrations
# 3                                Room service and Wifi        Picnic House
# 4                                           Restrauant        Celebrations
# ..                                                 ...                 ...
# 246  Swimming pool, Gym, Lobby and Bar, Restrauant,...  Private Apartments
# 247  Swimming pool, Gym, Lobby and Bar, Restrauant,...           Antariksh
# 248                  Restrauant, Room service and Wifi  Private Apartments
# 249                  Restrauant, Room service and Wifi           Antariksh
# 250                                     Gym, Game room        Celebrations
#
#                  amenities
# 0    Room service and Wifi
# ...

# %%
#Relationship between staying preference and the ammenities the visitors got for the same
plt.figure(figsize=(14,6))
sns.histplot(data=df2, x='amenities', y='WHERE DID YOU STAY?',color='purple')
# Out:
# <Axes: xlabel='amenities', ylabel='WHERE DID YOU STAY?'>

# %%
#Graph showing various amenities provided
plt.figure(figsize=(14,6))
sns.histplot(data=df2,x='amenities',color='red')
# Out:
# <Axes: xlabel='amenities', ylabel='Count'>

# %%
#Relationship between places visited and how did the visitors rate that place
df3 = data.loc[:, ['Places you visited in Lavasa','How would you Rate the activities and attraction']]
df3['Places'] = df3['Places you visited in Lavasa'].str.split(',').str[0]
# sns.catplot(data=df3, x='Places', y='How would you Rate the activities and attraction',aspect=3)
plt.figure(figsize=(14, 6))
sns.lineplot(x="Places", y="How would you Rate the activities and attraction",data=df3,color='red')
df3
# Out:
#                           Places you visited in Lavasa  \
# 0    Christ (Deemed to be University) , Pune Lavasa...
# 1    Christ (Deemed to be University) , Pune Lavasa...
# 2    Christ (Deemed to be University) , Pune Lavasa...
# 3    Christ (Deemed to be University) , Pune Lavasa...
# 4    Christ (Deemed to be University) , Pune Lavasa...
# ..                                                 ...
# 246  Christ (Deemed to be University) , Pune Lavasa...
# 247  Christ (Deemed to be University) , Pune Lavasa...
# 248  Lingya Waterfalls, Town Hall, Dasve Viewpoint,...
# 249          Lingya Waterfalls, Temghar Dam, Town Hall
# 250  Christ (Deemed to be University) , Pune Lavasa...
#
#      How would you Rate the activities and attraction  \
# 0                                                   3
# 1                                                   5
# 2                                                   1
# 3                                                   3
# ...

# %% [markdown]
# Insights-"Lingya Waterfall is highly rated by the visitors"

# %%
# plot_df1 = data.loc[:, ['Activities']]
# # plot_df1['AMENITIES YOU GOT'] = data['AMENITIES YOU GOT'].str.strip()
# plot_df1['Activities'] = data['Activities'].str.split(',')
# plot_df1 = plot_df1.explode('Activities').reset_index(drop=True)
# plot_df1.loc[:, ['Activities']] = plot_df1.loc[:, ['Activities']]
# sns.catplot(data=data, x=plot_df1['Activities'], y='How would you Rate the activities and attraction',aspect=25/6)


#Relationship between activities and how did the visitors rated them
df4 = data.loc[:, ['Activities','How would you Rate the activities and attraction']]
df4['ACTIVITIES'] = df4['Activities'].str.split(',').str[0]
plt.figure(figsize=(10, 6))
sns.lineplot(data=df4, x='ACTIVITIES', y='How would you Rate the activities and attraction',color='green')
df4
# Out:
#                                             Activities  \
# 0                                               Others
# 1    Trackless Train, Water sport, Trekking, Bird W...
# 2                                             Trekking
# 3                                               Others
# 4                                Water sport, Trekking
# ..                                                 ...
# 246  Trackless Train, Water sport, Trekking, Bird W...
# 247  Trackless Train, Water sport, Trekking, Bird W...
# 248          Trekking, Bird Watching, Waterfall Safari
# 249                    Bird Watching, Waterfall Safari
# 250                                      Bird Watching
#
#      How would you Rate the activities and attraction       ACTIVITIES
# 0                                                   3           Others
# 1                                                   5  Trackless Train
# 2                                                   1         Trekking
# ...

# %% [markdown]
# Insights-"Tackless Train is highly rated by the visitors"

# %%
# plot_df1 = data.loc[:, ['Restaurants You Visited']]
# # plot_df1['AMENITIES YOU GOT'] = data['AMENITIES YOU GOT'].str.strip()
# plot_df1['Restaurants You Visited'] = data['Restaurants You Visited'].str.split(',')
# plot_df1 = plot_df1.explode('Restaurants You Visited').reset_index(drop=True)
# plot_df1.loc[:, ['Restaurants You Visited']] = plot_df1.loc[:, ['Restaurants You Visited']]
# sns.catplot(data=data, x=plot_df1['Restaurants You Visited'], y='Worth of Money',aspect=25/4)

#Relationship between restaurants visited and was it worth the money

df5 = data.loc[:, ['Restaurants You Visited','Worth of Money']]
df5['restaurant'] = df5['Restaurants You Visited'].str.split(',').str[0]
plt.figure(figsize=(20,6))
sns.histplot(data=df5, x='restaurant', y='Worth of Money',color = 'teal')
df5
# Out:
#                                Restaurants You Visited  Worth of Money  \
# 0    Hotel Yuvraj, Hotel Shree Pure Veg, American D...               4
# 1    Hotel Ashrirwad, Hotel Garava, Hotel Yuvraj, H...               1
# 2      Hotel Ashrirwad, Hotel Yuvraj, College Canteens               3
# 3    Hotel Yuvraj, Hotel Shree Pure Veg, College Ca...               4
# 4    Hotel Ashrirwad, Hotel Garava, Hotel Shree Pur...               3
# ..                                                 ...             ...
# 246  Popsicles Cafe, Hotel Sai, College Canteens, S...               5
# 247  Hotel Ashrirwad, Hotel Garava, Hotel Yuvraj, H...               5
# 248  Hotel Ashrirwad, Hotel Garava, Hotel Yuvraj, S...               4
# 249   Hotel Garava, Hotel Yuvraj, Hotel Shree Pure Veg               1
# 250                       Hotel Shree Pure Veg, Others               3
#
#                restaurant
# 0            Hotel Yuvraj
# 1         Hotel Ashrirwad
# 2         Hotel Ashrirwad
# ...

# %% [markdown]
# Insights-"Hotel Aashirvad has more worth of money than the other"

# %% [markdown]
# GAP : "The food according to the Worth of Money is unsatisfactory and needs improvement in the quality and variety."

# %%
sns.catplot(data=data, x='HOTEL CHARGES /DAY', hue="WHERE DID YOU STAY?",aspect=27/18)

# %%
# Creating a 2 -D histogram for finding the frequency of visits according to the category of visitors

x=df1['purpose']
y=data['Frequency of Visit']
sns.histplot(x=x,y=y, bins=(30,30), cbar=True,cmap='pink')  
plt.xlabel('purpose')
plt.ylabel('Frequency of Visit')
plt.title('Visiting Relationship')
plt.show()

# %%
#Recommendation chart
count_data = data["Will you Recommend visiting Lavasa?"].value_counts()
plt.figure(figsize=(6, 6)) 
plt.pie(count_data, labels=count_data.index, autopct='%1.1f%%', startangle=140)
plt.title('Will you Recommend visiting Lavasa?')
plt.axis('equal')
plt.show()

# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Python program to generate WordCloud
# importing all necessary modules
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
comment_words = ''
stopwords = set(STOPWORDS)

# iterating through the csv file
for val in data['Improvements needed']:
	
	# typecasting each val to string
	val = str(val)

	# splitting the value
	tokens = val.split()
	
	# Converting each token into lowercase
	for i in range(len(tokens)):
		tokens[i] = tokens[i].lower()
	
	comment_words += " ".join(tokens)+" "

wordcloud = WordCloud(width = 800, height = 800,
				background_color ='white',
				stopwords = stopwords,
				min_font_size = 10).generate(comment_words)

# plotting the WordCloud image					 
plt.figure(figsize = (5, 5), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %% [markdown]
# Overall, Lavasa appears to be a destination with a young, budget-conscious, and predominantly solo-traveler demographic.
# Visitors are drawn to outdoor activities like trekking and are generally satisfied with their experiences, although there is room for improvement in food satisfaction.
# The recommendation rate suggests a strong appeal for future visitors.
